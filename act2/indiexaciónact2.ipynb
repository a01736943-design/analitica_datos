# %%
#INSTALAR LIBRERIAS
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Convertimos el dataset en dataframe
df= pd.read_csv("listings.csv")
df
# Out:
#                        id                                       listing_url  \
# 0                    8521                 https://www.airbnb.com/rooms/8521
# 1                   11169                https://www.airbnb.com/rooms/11169
# 2                   19581                https://www.airbnb.com/rooms/19581
# 3                   27498                https://www.airbnb.com/rooms/27498
# 4                   79762                https://www.airbnb.com/rooms/79762
# ...                   ...                                               ...
# 1370  1442190452341432060  https://www.airbnb.com/rooms/1442190452341432060
# 1371  1443555192209357989  https://www.airbnb.com/rooms/1443555192209357989
# 1372  1443585853586366833  https://www.airbnb.com/rooms/1443585853586366833
# 1373  1447874951198409920  https://www.airbnb.com/rooms/1447874951198409920
# 1374  1447875564779712913  https://www.airbnb.com/rooms/1447875564779712913
#
#            scrape_id last_scraped       source  \
# ...

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1375 entries, 0 to 1374
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            1375 non-null   int64
#  1   listing_url                                   1375 non-null   object
#  2   scrape_id                                     1375 non-null   int64
#  3   last_scraped                                  1375 non-null   object
#  4   source                                        1375 non-null   object
#  5   name                                          1375 non-null   object
#  6   description                                   1366 non-null   object
#  7   neighborhood_overview                         705 non-null    object
#  8   picture_url                                   1375 non-null   object
# ...

# %%
# Un array 2D con las columnas (Array 2D)
columnas1 = df[['host_name', 'host_since','neighbourhood', 'property_type', 'room_type', 'price']] #pueden ser consecutivas o no consecutivas
columnas1
# Out:
#      host_name  host_since            neighbourhood  \
# 0        Janet  2010-12-01  Neighborhood highlights
# 1     Judith L  2009-09-24  Neighborhood highlights
# 2       Marc E  2010-01-27                      NaN
# 3       Marc E  2010-01-27                      NaN
# 4        Kevin  2011-03-08  Neighborhood highlights
# ...        ...         ...                      ...
# 1370     Blake  2016-05-25  Neighborhood highlights
# 1371    Taskin  2014-05-05                      NaN
# 1372    Taskin  2014-05-05                      NaN
# 1373   Compass  2014-09-02  Neighborhood highlights
# 1374   Compass  2014-09-02  Neighborhood highlights
#
#                           property_type        room_type    price
# 0                    Entire rental unit  Entire home/apt  $270.00
# 1                 Private room in condo     Private room  $154.00
# 2     Private room in bed and breakfast     Private room  $154.00
# 3     Private room in bed and breakfast     Private room  $183.00
# ...

# %%
# Un array 2D con las filas (Array 2D)
filas1 = df.iloc[[1, 50, 499, 500, 605,]+list(range(100,200)),:]
filas1
# Out:
#                      id                                      listing_url  \
# 1                 11169               https://www.airbnb.com/rooms/11169
# 50              3334098             https://www.airbnb.com/rooms/3334098
# 499            50073035            https://www.airbnb.com/rooms/50073035
# 500            50118419            https://www.airbnb.com/rooms/50118419
# 605  589165201873039084  https://www.airbnb.com/rooms/589165201873039084
# ..                  ...                                              ...
# 195            15023471            https://www.airbnb.com/rooms/15023471
# 196            15056521            https://www.airbnb.com/rooms/15056521
# 197            15084907            https://www.airbnb.com/rooms/15084907
# 198            15125756            https://www.airbnb.com/rooms/15125756
# 199            15191990            https://www.airbnb.com/rooms/15191990
#
#           scrape_id last_scraped           source  \
# ...

# %%
# Un array 2D con las filas (Array 2D)
filas2 = df.iloc[[125,252,700,1000,1250]+list(range(300,550))+list(range(1250,1375)),: ]
filas2
filas3= filas2[['host_id', 'host_location', 'host_acceptance_rate','bathrooms', 'amenities','review_scores_value']]
filas3
# Out:
#         host_id                 host_location host_acceptance_rate  bathrooms  \
# 125    21631889                 Cambridge, MA                 100%        2.0
# 252     7421025                 Cambridge, MA                  NaN        1.0
# 700   373675137                    Boston, MA                  94%        1.0
# 1000    2111161             Mid-Cambridge, MA                  91%        2.5
# 1250  373675137                    Boston, MA                  94%        NaN
# ...         ...                           ...                  ...        ...
# 1370   73885693                 Cambridge, MA                  79%        1.0
# 1371   15154687  Massachusetts, United States                 100%        2.0
# 1372   15154687  Massachusetts, United States                 100%        2.0
# 1373   20857768                    Boston, MA                  57%        2.0
# 1374   20857768                    Boston, MA                  57%        1.0
#
# ...

# %%
# Acceder a más de una Columna (Array 2D)
_dfde50 = df[['latitude',
'longitude',
'accommodates',
'bathrooms',
'bedrooms',
'beds',
'price',
'minimum_nights',
'maximum_nights',
'minimum_minimum_nights',
'maximum_minimum_nights',
'minimum_maximum_nights',
'maximum_maximum_nights',
'minimum_nights_avg_ntm',
'maximum_nights_avg_ntm',
'availability_30',
'availability_60',
'availability_90',
'availability_365',
'number_of_reviews',
'number_of_reviews_ltm',
'number_of_reviews_l30d',
'review_scores_rating',
'review_scores_accuracy',
'review_scores_cleanliness',
'review_scores_checkin',
'review_scores_communication',
'review_scores_location',
'review_scores_value',
'host_listings_count',
'host_total_listings_count',
'id',
'host_id',
'neighbourhood_cleansed',
'neighbourhood_group_cleansed',
'property_type',
'room_type',
'host_response_time',
'host_response_rate',
'host_acceptance_rate',
'host_is_superhost',
'host_verifications',
'host_identity_verified',
'has_availability',
'instant_bookable',
'amenities',
'host_since',
'host_location',
'host_name',
'listing_url']] #pueden ser consecutivas o no consecutivas
_dfde50
# Out:
#        latitude  longitude  accommodates  bathrooms  bedrooms  beds    price  \
# 0     42.382580 -71.136460             5        1.0       2.0   2.0  $270.00
# 1     42.396300 -71.131350             3        1.0       1.0   0.0  $154.00
# 2     42.362580 -71.096030             1        1.0       1.0   1.0  $154.00
# 3     42.362540 -71.096980             2        1.0       1.0   1.0  $183.00
# 4     42.369500 -71.099210             4        1.0       2.0   2.0  $300.00
# ...         ...        ...           ...        ...       ...   ...      ...
# 1370  42.365136 -71.099673             4        1.0       2.0   3.0  $261.00
# 1371  42.363767 -71.108582             2        2.0       1.0   2.0  $104.00
# 1372  42.363650 -71.109660             2        2.0       1.0   1.0   $88.00
# 1373  42.363145 -71.087892             5        2.0       2.0   2.0  $290.00
# 1374  42.363150 -71.087890             3        1.0       1.0   1.0  $242.00
#
# ...

# %%
#Convertir array a CSV
_dfde50.to_csv("actividad2.csv")
