# %%
#INSTALAR LIBRERIAS
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: seaborn in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: pandas>=1.2 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: openpyxl in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages (from openpyxl) (2.0.0)

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('listings.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1375 entries, 0 to 1374
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            1375 non-null   int64
#  1   listing_url                                   1375 non-null   object
#  2   scrape_id                                     1375 non-null   int64
#  3   last_scraped                                  1375 non-null   object
#  4   source                                        1375 non-null   object
#  5   name                                          1375 non-null   object
#  6   description                                   1366 non-null   object
#  7   neighborhood_overview                         705 non-null    object
#  8   picture_url                                   1375 non-null   object
#  9   host_id                                       1375 non-null   int64
#  10  host_url                                      1375 non-null   object
#  11  host_name                                     1336 non-null   object
#  12  host_since                                    1336 non-null   object
#  13  host_location                                 1105 non-null   object
#  14  host_about                                    866 non-null    object
#  15  host_response_time                            1238 non-null   object
#  16  host_response_rate                            1238 non-null   object
#  17  host_acceptance_rate                          1254 non-null   object
#  18  host_is_superhost                             1239 non-null   object
#  19  host_thumbnail_url                            1336 non-null   object
#  20  host_picture_url                              1336 non-null   object
#  21  host_neighbourhood                            1299 non-null   object
#  22  host_listings_count                           1336 non-null   float64
#  23  host_total_listings_count                     1336 non-null   float64
#  24  host_verifications                            1336 non-null   object
#  25  host_has_profile_pic                          1336 non-null   object
#  26  host_identity_verified                        1336 non-null   object
#  27  neighbourhood                                 705 non-null    object
#  28  neighbourhood_cleansed                        1375 non-null   object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      1375 non-null   float64
#  31  longitude                                     1375 non-null   float64
#  32  property_type                                 1375 non-null   object
#  33  room_type                                     1375 non-null   object
#  34  accommodates                                  1375 non-null   int64
#  35  bathrooms                                     1137 non-null   float64
#  36  bathrooms_text                                1374 non-null   object
#  37  bedrooms                                      1299 non-null   float64
#  38  beds                                          1135 non-null   float64
#  39  amenities                                     1375 non-null   object
#  40  price                                         1130 non-null   object
#  41  minimum_nights                                1375 non-null   int64
#  42  maximum_nights                                1375 non-null   int64
#  43  minimum_minimum_nights                        1374 non-null   float64
#  44  maximum_minimum_nights                        1374 non-null   float64
#  45  minimum_maximum_nights                        1374 non-null   float64
#  46  maximum_maximum_nights                        1374 non-null   float64
#  47  minimum_nights_avg_ntm                        1375 non-null   float64
#  48  maximum_nights_avg_ntm                        1375 non-null   float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              1354 non-null   object
#  51  availability_30                               1375 non-null   int64
#  52  availability_60                               1375 non-null   int64
#  53  availability_90                               1375 non-null   int64
#  54  availability_365                              1375 non-null   int64
#  55  calendar_last_scraped                         1375 non-null   object
#  56  number_of_reviews                             1375 non-null   int64
#  57  number_of_reviews_ltm                         1375 non-null   int64
#  58  number_of_reviews_l30d                        1375 non-null   int64
#  59  availability_eoy                              1375 non-null   int64
#  60  number_of_reviews_ly                          1375 non-null   int64
#  61  estimated_occupancy_l365d                     1375 non-null   int64
#  62  estimated_revenue_l365d                       1130 non-null   float64
#  63  first_review                                  1039 non-null   object
#  64  last_review                                   1039 non-null   object
#  65  review_scores_rating                          1039 non-null   float64
#  66  review_scores_accuracy                        1039 non-null   float64
#  67  review_scores_cleanliness                     1039 non-null   float64
#  68  review_scores_checkin                         1039 non-null   float64
#  69  review_scores_communication                   1039 non-null   float64
#  70  review_scores_location                        1039 non-null   float64
#  71  review_scores_value                           1039 non-null   float64
#  72  license                                       484 non-null    object
#  73  instant_bookable                              1375 non-null   object
#  74  calculated_host_listings_count                1375 non-null   int64
#  75  calculated_host_listings_count_entire_homes   1375 non-null   int64
#  76  calculated_host_listings_count_private_rooms  1375 non-null   int64
#  77  calculated_host_listings_count_shared_rooms   1375 non-null   int64
#  78  reviews_per_month                             1039 non-null   float64
# dtypes: float64(24), int64(20), object(35)
# memory usage: 848.8+ KB

# %%
filtro_a= df["host_name"].value_counts().head(5).index.tolist()
filtro_a = df[df["host_name"].isin(filtro_a)]
filtro_a.head()
filtro_a.to_csv("filtro_a.csv")

# %%
filtro_b = df[df["host_since"] > "2020-12-31"] 
filtro_b.to_csv("filtro_b.csv")
filtro_b
# Out:
#                        id                                       listing_url  \
# 286              24304200             https://www.airbnb.com/rooms/24304200
# 338              32441363             https://www.airbnb.com/rooms/32441363
# 467              48282995             https://www.airbnb.com/rooms/48282995
# 468              48286373             https://www.airbnb.com/rooms/48286373
# 478              49026967             https://www.airbnb.com/rooms/49026967
# ...                   ...                                               ...
# 1342  1397288373908458862  https://www.airbnb.com/rooms/1397288373908458862
# 1345  1402383133479732766  https://www.airbnb.com/rooms/1402383133479732766
# 1347  1404363541488912949  https://www.airbnb.com/rooms/1404363541488912949
# 1352  1413037033838490901  https://www.airbnb.com/rooms/1413037033838490901
# 1360  1432631054379149017  https://www.airbnb.com/rooms/1432631054379149017
#
#            scrape_id last_scraped       source  \
# 286   20250625193454   2025-06-26  city scrape
# 338   20250625193454   2025-06-26  city scrape
# 467   20250625193454   2025-06-27  city scrape
# 468   20250625193454   2025-06-27  city scrape
# 478   20250625193454   2025-06-26  city scrape
# ...              ...          ...          ...
# 1342  20250625193454   2025-06-27  city scrape
# 1345  20250625193454   2025-06-26  city scrape
# 1347  20250625193454   2025-06-26  city scrape
# 1352  20250625193454   2025-06-26  city scrape
# 1360  20250625193454   2025-06-27  city scrape
#
#                                                    name  \
# 286   (2) Beautiful N. Cambridge Private Room Two Tw...
# 338         (1) North Cambridge Private Bedroom Full Be
# 467                 The Modica Estates with Dave room A
# 468                The Modica Estates  with Dave room B
# 478      Cambridgeport Charming 2nd floor 2-room studio
# ...                                                 ...
# 1342                     Cozy one-bed in Harvard Square
# 1345  Chinatown Upscale Penthouse w/Balcony Gym Parking
# 1347  Chinatown Central 2BR near Boston Common Tufts...
# 1352                         Luxury 2b2b East Cambridge
# 1360   Bright & Spacious 3BR Condo in Central Cambridge
#
#                                             description  \
# 286   This bedroom for two (2 twin beds) features be...
# 338   This bedroom (1 full bed) features beautiful n...
# 467   Another listing from the legendary Modica Esta...
# 468   Another listing from The legendary Modica Esta...
# 478   Cambridge Prime Location, 8 min walk to Centra...
# ...                                                 ...
# 1342  Charming one-bedroom in quaint antique house j...
# 1345  ***NOTE: BOSTON CHINATOWN Penthouse slps 5 ***...
# 1347  **Location: Boston Downtown Chinatown **<br />...
# 1352  Your family will be close to everything when y...
# 1360  Welcome to your Cambridge home away from home!...
#
#                                   neighborhood_overview  \
# 286   Quiet, safe neighborhood nearby Davis Square a...
# 338   This is a pleasant residential neighborhood, a...
# 467   The neighborhood is known as Area 4 of Cambrid...
# 468                                                 NaN
# 478                                                 NaN
# ...                                                 ...
# 1342                                                NaN
# 1345  Nestled in the heart of Boston, our apartment ...
# 1347  Nestled in the heart of Boston, our apartment ...
# 1352                                                NaN
# 1360                                                NaN
#
#                                             picture_url    host_id  ...  \
# 286   https://a0.muscache.com/pictures/9c2596b4-37da...  519702802  ...
# 338   https://a0.muscache.com/pictures/89ade1e8-e229...  519702802  ...
# 467   https://a0.muscache.com/pictures/c5d33cf7-bba6...  389667772  ...
# 468   https://a0.muscache.com/pictures/3dea6a58-6107...  389667772  ...
# 478   https://a0.muscache.com/pictures/miso/Hosting-...  394741679  ...
# ...                                                 ...        ...  ...
# 1342  https://a0.muscache.com/pictures/miso/Hosting-...  689492120  ...
# 1345  https://a0.muscache.com/pictures/prohost-api/H...  463475392  ...
# 1347  https://a0.muscache.com/pictures/hosting/Hosti...  463475392  ...
# 1352  https://a0.muscache.com/pictures/hosting/Hosti...  680762957  ...
# 1360  https://a0.muscache.com/pictures/miso/Hosting-...  698396149  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 286                         4.97                   4.91                4.84
# 338                         4.95                   4.92                4.85
# 467                         4.89                   4.87                4.75
# 468                         4.89                   4.88                4.81
# 478                         4.67                   4.83                4.50
# ...                          ...                    ...                 ...
# 1342                         NaN                    NaN                 NaN
# 1345                        4.75                   5.00                4.75
# 1347                        4.50                   4.50                4.00
# 1352                         NaN                    NaN                 NaN
# 1360                        5.00                   5.00                5.00
#
#          license instant_bookable calculated_host_listings_count  \
# 286          NaN                f                              2
# 338          NaN                f                              2
# 467   STR-109785                t                              2
# 468   STR-109785                t                              2
# 478          NaN                f                             16
# ...          ...              ...                            ...
# 1342         NaN                f                              1
# 1345         NaN                t                             30
# 1347         NaN                t                             30
# 1352         NaN                t                              1
# 1360         NaN                t                              1
#
#      calculated_host_listings_count_entire_homes  \
# 286                                            0
# 338                                            0
# 467                                            0
# 468                                            0
# 478                                            4
# ...                                          ...
# 1342                                           1
# 1345                                          30
# 1347                                          30
# 1352                                           1
# 1360                                           1
#
#      calculated_host_listings_count_private_rooms  \
# 286                                             2
# 338                                             2
# 467                                             2
# 468                                             2
# 478                                            12
# ...                                           ...
# 1342                                            0
# 1345                                            0
# 1347                                            0
# 1352                                            0
# 1360                                            0
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 286                                            0              5.25
# 338                                            0              5.42
# 467                                            0              6.85
# 468                                            0              6.50
# 478                                            0              0.38
# ...                                          ...               ...
# 1342                                           0               NaN
# 1345                                           0              2.73
# 1347                                           0              3.91
# 1352                                           0               NaN
# 1360                                           0              5.00
#
# [230 rows x 79 columns]

# %%
filtro_c = df[df["host_response_time"] == "within a day"]
filtro_c.to_csv("filtro_c.csv")

# %%
filtro_d= df.iloc[200::200,:] #Filas con incrementos de 200 a partir de la fila 200
filtro_d
filtro_d.to_csv("filtro_d.csv")

# %%
filtro_e = df[df["room_type"].isin(["Entire home/apt", "Private room"])]
filtro_e.to_csv("filtro_e.csv")

# %%
filtro_f = df[df["beds"] <= 4]
filtro_f.to_csv("filtro_f.csv")

# %%
filtro_g = df[df["host_is_superhost"] == "t"]
filtro_g.to_csv("filtro_g.csv")

# %%
#Columnas incrementales en un fator
filtro_h= df.iloc[:, 1::2] #Columnas con incrementos de 2 a partir de la columna
filtro_h.to_csv("filtro_h.csv")
